# %% [markdown]
# # 🥦 Klasifikasi Kesegaran Sayur & Buah
# ### Transfer Learning MobileNetV2 — Feature Extraction
#
# **Dataset:** sayur_buah_gambar
# **Total gambar:** 68.752 | **Total kelas:** 30
#
# **Struktur dataset:**
# ```
# sayur_buah_gambar/
# ├── buah/
# │   ├── unripe/   ← apple_unripe/, banana_unripe/, ...
# │   ├── ripe/
# │   ├── overripe/
# │   └── rotten/
# └── sayur/
#     ├── fresh/   ← cabe_fresh/, tomat_fresh/, ...
#     └── rotten/
# ```
#
# **Keputusan desain:**
# | Aspek | Keputusan | Alasan |
# |---|---|---|
# | Model | MobileNetV2 | Ringan, cocok untuk mobile |
# | Fase training | 1 fase (Feature Extraction) | Hemat RAM 12 GB; dataset sudah cukup besar |
# | Imbalance | Undersampling + Class weight | Hemat RAM dan balance |
# | Augmentasi | On-the-fly di custom Sequence | Hemat disk, variasi lebih besar per epoch |
# | Out-of-scope | Confidence threshold + entropy | Menolak gambar di luar dataset |
#
# **Label final model:** `nama_item` → `jenis_item` → `kondisi_fisik`
# Contoh output: `{'nama_item': 'apple', 'jenis_item': 'Buah', 'kondisi_fisik': 'Matang', 'confidence': '94.3%'}`

# %% [markdown]
# ## 1. Setup & Instalasi Library

# %%
# Uncomment jika belum terinstall
# !pip install tensorflow matplotlib seaborn scikit-learn pillow

import os
import json
import random
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
from pathlib import Path
from collections import defaultdict
import shutil, zipfile
from google.colab import drive

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
)
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import Sequence, to_categorical

from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix

warnings.filterwarnings('ignore')

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow  :", tf.__version__)
print("GPU tersedia:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow  : 2.20.0
# GPU tersedia: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Konfigurasi

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Copy dataset di Drive ke lokal
ZIP_PATH   = "/content/drive/MyDrive/sayur_buah_gambar.zip"
LOCAL_DIR  = "/content/sayur_buah_gambar"

if not os.path.exists(LOCAL_DIR):
    print("Menyalin zip dari Drive ke lokal...")
    shutil.copy(ZIP_PATH, "/content/sayur_buah_gambar.zip")   # ~1-2 menit
    print("Mengekstrak...")
    with zipfile.ZipFile("/content/sayur_buah_gambar.zip") as z:
        z.extractall("/content/")
    print("Selesai!")
else:
    print("Dataset sudah ada di lokal, skip copy.")
# Out:
# Menyalin zip dari Drive ke lokal...
# Mengekstrak...
# Selesai!

# %%
# Sesuaikan path ini
DATASET_DIR = "/content/sayur_buah_gambar"

IMG_SIZE   = 224
BATCH_SIZE = 32
VAL_SPLIT  = 0.15
TEST_SPLIT = 0.15

EPOCHS = 20        # EarlyStopping biasanya berhenti jauh lebih awal
LR     = 1e-3

# Cap jumlah gambar per kelas
# Tujuan: percepat training + kurangi dominasi kelas mayoritas
# Kelas di bawah cap tidak terpengaruh (tetap pakai semua gambarnya)
MAX_PER_CLASS = 1500

# Threshold out-of-scope detection
CONFIDENCE_THRESHOLD = 0.60
ENTROPY_THRESHOLD    = 2.80

# Mapping folder → label standar
KONDISI_MAP = {
    ('buah', 'unripe')   : ('Buah', 'Mentah'),
    ('buah', 'ripe')     : ('Buah', 'Matang'),
    ('buah', 'overripe') : ('Buah', 'Terlalu Matang'),
    ('buah', 'rotten')   : ('Buah', 'Busuk'),
    ('sayur', 'fresh')   : ('Sayur', 'Segar'),
    ('sayur', 'rotten')  : ('Sayur', 'Busuk'),
}

print("Mapping label:")
for (jenis, folder), (jenis_std, kondisi) in KONDISI_MAP.items():
    print(f"  {jenis:<6}/{folder:<10} → {jenis_std}, {kondisi}")
print(f"\nMAX_PER_CLASS : {MAX_PER_CLASS}")
# Out:
# Mapping label:
#   buah  /unripe     → Buah, Mentah
#   buah  /ripe       → Buah, Matang
#   buah  /overripe   → Buah, Terlalu Matang
#   buah  /rotten     → Buah, Busuk
#   sayur /fresh      → Sayur, Segar
#   sayur /rotten     → Sayur, Busuk
#
# MAX_PER_CLASS : 1500

# %% [markdown]
# ## 3. Scan Dataset & Buat Label Standar

# %%
dataset_path = Path(DATASET_DIR)
extensions   = {'.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG'}

all_paths    = []
all_labels   = []
all_meta     = []
label_counts = defaultdict(int)
label_skipped = defaultdict(int)   # log gambar yang diskip karena cap

for jenis_dir in ['buah', 'sayur']:
    jenis_path = dataset_path / jenis_dir
    if not jenis_path.exists():
        print(f"[WARN] Folder tidak ditemukan: {jenis_path}")
        continue

    for kondisi_folder in sorted(jenis_path.iterdir()):
        if not kondisi_folder.is_dir():
            continue
        kondisi_key = kondisi_folder.name.lower()
        map_key = (jenis_dir, kondisi_key)

        if map_key not in KONDISI_MAP:
            print(f"[SKIP] Tidak ada mapping untuk: {jenis_dir}/{kondisi_key}")
            continue

        jenis_std, kondisi_std = KONDISI_MAP[map_key]

        for item_folder in sorted(kondisi_folder.iterdir()):
            if not item_folder.is_dir():
                continue

            raw_name  = item_folder.name.lower()
            nama_item = raw_name
            for suffix in ['_unripe', '_ripe', '_overripe', '_rotten', '_fresh']:
                nama_item = nama_item.replace(suffix, '')

            imgs  = [f for f in item_folder.iterdir() if f.suffix in extensions]
            label = f"{nama_item}||{jenis_std}||{kondisi_std}"

            # Cap per kelas: acak dulu agar tidak bias ke file awal
            if len(imgs) > MAX_PER_CLASS:
                random.shuffle(imgs)
                label_skipped[label] += len(imgs) - MAX_PER_CLASS
                imgs = imgs[:MAX_PER_CLASS]

            for img_path in imgs:
                all_paths.append(str(img_path))
                all_labels.append(label)
                all_meta.append({
                    'path'         : str(img_path),
                    'nama_item'    : nama_item,
                    'jenis_item'   : jenis_std,
                    'kondisi_fisik': kondisi_std,
                    'label'        : label
                })
                label_counts[label] += 1

print(f"Total gambar dipakai : {len(all_paths):,}")
print(f"Total label          : {len(label_counts)}")

if label_skipped:
    skipped_total = sum(label_skipped.values())
    print(f"\nGambar di-cap (diskip): {skipped_total:,}")
    print(f"{'Label':<40} {'Dipakai':>8} {'Diskip':>8}")
    print("-" * 60)
    for lbl in sorted(label_skipped):
        parts = lbl.split('||')
        name  = f"{parts[0]}|{parts[2]}"
        print(f"  {name:<38} {label_counts[lbl]:>8,} {label_skipped[lbl]:>8,}")

print()
df_meta = pd.DataFrame(all_meta)
print("Label unik yang ditemukan:")
for lbl, cnt in sorted(label_counts.items()):
    parts = lbl.split('||')
    capped = ' ← capped' if label_skipped.get(lbl, 0) > 0 else ''
    print(f"  {parts[0]:<15} | {parts[1]:<6} | {parts[2]:<15} : {cnt:>5} gambar{capped}")
# Out:
# Total gambar dipakai : 24,242
# Total label          : 30
#
# Gambar di-cap (diskip): 44,510
# Label                                     Dipakai   Diskip
# ------------------------------------------------------------
#   apple|Busuk                               1,500    2,932
#   apple|Matang                              1,500    1,931
#   banana|Busuk                              1,500    2,543
#   banana|Matang                             1,500    1,972
#   carrot|Busuk                              1,500      918
#   carrot|Segar                              1,500    8,398
#   orange|Busuk                              1,500    1,792
#   orange|Matang                             1,500    9,331
#   tomat|Busuk                               1,500    2,512
#   tomat|Segar                               1,500   12,181
#
# Label unik yang ditemukan:
#   apple           | Buah   | Busuk           :  1500 gambar ← capped
#   apple           | Buah   | Matang          :  1500 gambar ← capped
#   apple           | Buah   | Mentah          :    84 gambar
#   apple           | Buah   | Terlalu Matang  :   335 gambar
#   banana          | Buah   | Busuk           :  1500 gambar ← capped
#   banana          | Buah   | Matang          :  1500 gambar ← capped
#   banana          | Buah   | Mentah          :   533 gambar
#   banana          | Buah   | Terlalu Matang  :   329 gambar
#   cabe            | Sayur  | Busuk           :   314 gambar
#   cabe            | Sayur  | Segar           :   311 gambar
#   carrot          | Sayur  | Busuk           :  1500 gambar ← capped
#   carrot          | Sayur  | Segar           :  1500 gambar ← capped
#   grape           | Buah   | Busuk           :   609 gambar
#   grape           | Buah   | Matang          :   111 gambar
#   grape           | Buah   | Mentah          :   226 gambar
#   grape           | Buah   | Terlalu Matang  :   124 gambar
#   mango           | Buah   | Busuk           :   593 gambar
#   mango           | Buah   | Matang          :   605 gambar
#   mango           | Buah   | Mentah          :   179 gambar
#   mango           | Buah   | Terlalu Matang  :   112 gambar
#   orange          | Buah   | Busuk           :  1500 gambar ← capped
#   orange          | Buah   | Matang          :  1500 gambar ← capped
#   orange          | Buah   | Mentah          :    62 gambar
#   orange          | Buah   | Terlalu Matang  :    61 gambar
#   potato          | Sayur  | Busuk           :  1386 gambar
#   potato          | Sayur  | Segar           :  1150 gambar
#   timun           | Sayur  | Busuk           :  1014 gambar
#   timun           | Sayur  | Segar           :  1104 gambar
#   tomat           | Sayur  | Busuk           :  1500 gambar ← capped
#   tomat           | Sayur  | Segar           :  1500 gambar ← capped

# %%
CLASS_NAMES = sorted(label_counts.keys())
NUM_CLASSES = len(CLASS_NAMES)

label2idx = {name: idx for idx, name in enumerate(CLASS_NAMES)}
idx2label = {idx: name for name, idx in label2idx.items()}

print(f"Total kelas : {NUM_CLASSES}")
print()
print(f"{'Idx':<4} {'Label'}")
print("-" * 55)
for idx, name in enumerate(CLASS_NAMES):
    parts = name.split('||')
    print(f"[{idx:>2}] {parts[0]:<15} | {parts[1]:<6} | {parts[2]}")
# Out:
# Total kelas : 30
#
# Idx  Label
# -------------------------------------------------------
# [ 0] apple           | Buah   | Busuk
# [ 1] apple           | Buah   | Matang
# [ 2] apple           | Buah   | Mentah
# [ 3] apple           | Buah   | Terlalu Matang
# [ 4] banana          | Buah   | Busuk
# [ 5] banana          | Buah   | Matang
# [ 6] banana          | Buah   | Mentah
# [ 7] banana          | Buah   | Terlalu Matang
# [ 8] cabe            | Sayur  | Busuk
# [ 9] cabe            | Sayur  | Segar
# [10] carrot          | Sayur  | Busuk
# [11] carrot          | Sayur  | Segar
# [12] grape           | Buah   | Busuk
# [13] grape           | Buah   | Matang
# [14] grape           | Buah   | Mentah
# [15] grape           | Buah   | Terlalu Matang
# [16] mango           | Buah   | Busuk
# [17] mango           | Buah   | Matang
# [18] mango           | Buah   | Mentah
# [19] mango           | Buah   | Terlalu Matang
# [20] orange          | Buah   | Busuk
# [21] orange          | Buah   | Matang
# [22] orange          | Buah   | Mentah
# [23] orange          | Buah   | Terlalu Matang
# [24] potato          | Sayur  | Busuk
# [25] potato          | Sayur  | Segar
# [26] timun           | Sayur  | Busuk
# [27] timun           | Sayur  | Segar
# [28] tomat           | Sayur  | Busuk
# [29] tomat           | Sayur  | Segar

# %% [markdown]
# ## 4. Eksplorasi & Visualisasi Dataset

# %%
df_summary = (df_meta
              .groupby(['jenis_item', 'kondisi_fisik'])
              .size()
              .reset_index(name='jumlah'))
print(df_summary.to_string(index=False))
print(f"\nTotal: {df_summary['jumlah'].sum():,} gambar")

# Rasio imbalance
counts = list(label_counts.values())
print(f"\nKelas terbesar  : {max(counts):,} ({CLASS_NAMES[np.argmax(counts)]})")
print(f"Kelas terkecil  : {min(counts):,} ({CLASS_NAMES[np.argmin(counts)]})")
print(f"Rasio imbalance : {max(counts)/min(counts):.0f}:1")
# Out:
# jenis_item  kondisi_fisik  jumlah
#       Buah          Busuk    5702
#       Buah         Matang    5216
#       Buah         Mentah    1084
#       Buah Terlalu Matang     961
#      Sayur          Busuk    5714
#      Sayur          Segar    5565
#
# Total: 24,242 gambar
#
# Kelas terbesar  : 1,500 (banana||Buah||Matang)
# Kelas terkecil  : 61 (banana||Buah||Busuk)
# Rasio imbalance : 25:1

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

df_buah  = df_meta[df_meta['jenis_item'] == 'Buah']
order_buah = ['Mentah', 'Matang', 'Terlalu Matang', 'Busuk']
counts_buah = [len(df_buah[df_buah['kondisi_fisik'] == k]) for k in order_buah]
bars = axes[0].bar(order_buah, counts_buah,
                   color=['#aed6a0','#3b6d11','#854f0b','#a32d2d'],
                   alpha=0.85, edgecolor='white')
axes[0].bar_label(bars, padding=3, fmt='%d')
axes[0].set_title('Distribusi Kondisi — Buah', fontweight='bold')
axes[0].set_ylabel('Jumlah Gambar')
axes[0].grid(axis='y', alpha=0.3)

df_sayur = df_meta[df_meta['jenis_item'] == 'Sayur']
order_sayur = ['Segar', 'Busuk']
counts_sayur = [len(df_sayur[df_sayur['kondisi_fisik'] == k]) for k in order_sayur]
bars2 = axes[1].bar(order_sayur, counts_sayur,
                    color=['#3b6d11','#a32d2d'],
                    alpha=0.85, edgecolor='white')
axes[1].bar_label(bars2, padding=3, fmt='%d')
axes[1].set_title('Distribusi Kondisi — Sayur', fontweight='bold')
axes[1].set_ylabel('Jumlah Gambar')
axes[1].grid(axis='y', alpha=0.3)

plt.suptitle('Distribusi Gambar per Kondisi', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('distribusi_kondisi.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5. Persiapan Data — Split + Class Weight + Augmentasi
#
# **Augmentasi on-the-fly:**
# Augmentasi diintegrasikan langsung menggunakan `Keras Preprocessing Layers` (atau melalui pipeline tf.data), sehingga komputasi berjalan secara dinamis di memori, sangat menghemat penyimpanan disk, dan secara otomatis memberikan variasi gambar yang unik pada setiap putaran epoch.

# %%
paths  = np.array(all_paths)
labels = np.array(all_labels)

# Stratified split 70 / 15 / 15
X_temp, X_test, y_temp, y_test = train_test_split(
    paths, labels,
    test_size=TEST_SPLIT,
    stratify=labels,
    random_state=SEED
)
val_ratio = VAL_SPLIT / (1 - TEST_SPLIT)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp,
    test_size=val_ratio,
    stratify=y_temp,
    random_state=SEED
)

y_train_idx = np.array([label2idx[l] for l in y_train])
y_val_idx   = np.array([label2idx[l] for l in y_val])
y_test_idx  = np.array([label2idx[l] for l in y_test])

print(f"Train : {len(X_train):,}")
print(f"Val   : {len(X_val):,}")
print(f"Test  : {len(X_test):,}")
# Out:
# Train : 16,968
# Val   : 3,637
# Test  : 3,637

# %%
# Hitung Class Weight
# compute_class_weight menghitung bobot invers-frekuensi:
# kelas dengan sedikit sampel → bobot besar → loss lebih tinggi jika salah
class_weights_arr = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=y_train_idx
)
class_weight_dict = {i: w for i, w in enumerate(class_weights_arr)}

print("Class weight (sampel):")
# Tampilkan 10 kelas dengan bobot tertinggi (kelas minoritas)
sorted_cw = sorted(class_weight_dict.items(), key=lambda x: x[1], reverse=True)
for idx, w in sorted_cw[:10]:
    lbl = CLASS_NAMES[idx].split('||')
    print(f"  [{idx:>2}] {lbl[0]:<15} | {lbl[2]:<16} → weight: {w:.3f}")
print(f"  ... (total {NUM_CLASSES} kelas)")
# Out:
# Class weight (sampel):
#   [23] orange          | Terlalu Matang   → weight: 13.153
#   [22] orange          | Mentah           → weight: 12.855
#   [ 2] apple           | Mentah           → weight: 9.586
#   [13] grape           | Matang           → weight: 7.345
#   [19] mango           | Terlalu Matang   → weight: 7.251
#   [15] grape           | Terlalu Matang   → weight: 6.577
#   [18] mango           | Mentah           → weight: 4.525
#   [14] grape           | Mentah           → weight: 3.580
#   [ 9] cabe            | Segar            → weight: 2.606
#   [ 8] cabe            | Busuk            → weight: 2.571
#   ... (total 30 kelas)

# %%
# tf.data pipeline

AUTOTUNE = tf.data.AUTOTUNE

def load_and_preprocess(path, label):
    """Baca & resize gambar, normalisasi ke [0,1]."""
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    return img, label

def augment_fn(img, label):
    """Augmentasi on-the-fly (hanya untuk training)."""
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_crop(img, size=[int(IMG_SIZE * 0.9), int(IMG_SIZE * 0.9), 3])
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.image.random_brightness(img, max_delta=0.15)
    img = tf.image.random_contrast(img, lower=0.85, upper=1.15)
    img = tf.image.random_saturation(img, lower=0.85, upper=1.15)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, label

def make_dataset(paths, labels_idx, augment=False, shuffle=False):
    """
    Buat tf.data.Dataset dengan:
    - parallel map  : baca banyak gambar sekaligus di CPU
    - prefetch      : siapkan batch berikutnya saat GPU masih proses batch sekarang
    - shuffle buffer: acak data setiap epoch
    """
    ds = tf.data.Dataset.from_tensor_slices(
        (paths, labels_idx.astype('int32'))
    )
    if shuffle:
        ds = ds.shuffle(buffer_size=len(paths), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(load_and_preprocess, num_parallel_calls=AUTOTUNE)

    if augment:
        ds = ds.map(augment_fn, num_parallel_calls=AUTOTUNE)

    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(AUTOTUNE)
    return ds


train_ds = make_dataset(X_train, y_train_idx, augment=True,  shuffle=True)
val_ds   = make_dataset(X_val,   y_val_idx,   augment=False, shuffle=False)
test_ds  = make_dataset(X_test,  y_test_idx,  augment=False, shuffle=False)

print(f"Train batches : {len(train_ds)}")
print(f"Val   batches : {len(val_ds)}")
print(f"Test  batches : {len(test_ds)}")
# Out:
# Train batches : 531
# Val   batches : 114
# Test  batches : 114

# %%
# Visualisasi sample batch setelah augmentasi (dari tf.data)
sample_imgs, sample_labels = next(iter(train_ds))
fig, axes = plt.subplots(2, 8, figsize=(18, 5))
for i, ax in enumerate(axes.flatten()):
    ax.imshow(sample_imgs[i].numpy())
    parts = CLASS_NAMES[sample_labels[i].numpy()].split('||')
    ax.set_title(f'{parts[0]}\n{parts[2]}', fontsize=7)
    ax.axis('off')
plt.suptitle('Sample Batch (Augmentasi On-the-fly, tf.data)', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Bangun Model MobileNetV2
#
# ```
# Input (224×224×3)
#     ↓
# MobileNetV2 — FROZEN (ImageNet weights)
#     ↓
# GlobalAveragePooling2D
#     ↓
# Dropout(0.3)
#     ↓
# Dense(256, relu)
#     ↓
# Dropout(0.2)
#     ↓
# Dense(30, softmax)
# ```
#
# **Kenapa 1 fase cukup?**
# - MobileNetV2 dilatih di ImageNet yang kaya gambar objek sehari-hari termasuk buah/sayur

# %%
def build_model(num_classes, img_size=224):
    """
    MobileNetV2 feature extraction (base model frozen sepenuhnya).
    Hanya head classifier yang dilatih.
    """
    # Base model: MobileNetV2 pretrained ImageNet, tanpa top layer
    base = MobileNetV2(
        input_shape=(img_size, img_size, 3),
        include_top=False,
        weights='imagenet'
    )
    base.trainable = False   # Freeze semua layer base model

    # Functional API
    inputs  = keras.Input(shape=(img_size, img_size, 3))
    x       = base(inputs, training=False)   # training=False penting agar BatchNorm tetap inference mode
    x       = layers.GlobalAveragePooling2D()(x)
    x       = layers.Dropout(0.3)(x)
    x       = layers.Dense(256, activation='relu')(x)
    x       = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = keras.Model(inputs, outputs, name='MobileNetV2_SayurBuah')
    return model, base


model, base_model = build_model(NUM_CLASSES, IMG_SIZE)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "MobileNetV2_SayurBuah"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │         7,710 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,593,630 (9.89 MB)
#  Trainable params: 335,646 (1.28 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
trainable     = np.sum([np.prod(w.shape) for w in model.trainable_weights])
non_trainable = np.sum([np.prod(w.shape) for w in model.non_trainable_weights])
print(f"Parameter trainable     : {trainable:,}  (head classifier)")
print(f"Parameter non-trainable : {non_trainable:,}  (MobileNetV2 frozen)")
print(f"Total                   : {trainable + non_trainable:,}")
print(f"\nEfisiensi RAM: hanya {trainable/(trainable+non_trainable)*100:.1f}% parameter yang dihitung gradiennya")
# Out:
# Parameter trainable     : 335,646  (head classifier)
# Parameter non-trainable : 2,257,984  (MobileNetV2 frozen)
# Total                   : 2,593,630
#
# Efisiensi RAM: hanya 12.9% parameter yang dihitung gradiennya

# %% [markdown]
# ## 7. Training — Feature Extraction dengan Class Weight

# %%
model.compile(
    optimizer=keras.optimizers.Adam(LR),
    loss='sparse_categorical_crossentropy',   # sparse: label integer, tidak perlu to_categorical
    metrics=['accuracy']
)

os.makedirs('checkpoints', exist_ok=True)

callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        'checkpoints/best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

print("=" * 60)
print("TRAINING — Feature Extraction (MobileNetV2 frozen)")
print(f"  Epochs     : {EPOCHS} (EarlyStopping patience=5)")
print(f"  LR         : {LR}")
print(f"  Batch      : {BATCH_SIZE}")
print(f"  ClassWeight: aktif (balanced)")
print(f"  Pipeline   : tf.data + prefetch (GPU tidak idle)")
print("=" * 60)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    class_weight=class_weight_dict,
    verbose=1
)
# Out:
# ============================================================
# TRAINING — Feature Extraction (MobileNetV2 frozen)
#   Epochs     : 20 (EarlyStopping patience=5)
#   LR         : 0.001
#   Batch      : 32
#   ClassWeight: aktif (balanced)
#   Pipeline   : tf.data + prefetch (GPU tidak idle)
# ============================================================
# Epoch 1/20
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.5229 - loss: 1.7305
# Epoch 1: val_accuracy improved from None to 0.83310, saving model to checkpoints/best_model.keras
#
# Epoch 1: finished saving model to checkpoints/best_model.keras
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 167s 273ms/step - accuracy: 0.6626 - loss: 1.1689 - val_accuracy: 0.8331 - val_loss: 0.5325 - learning_rate: 0.0010
# Epoch 2/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7998 - loss: 0.6307
# Epoch 2: val_accuracy improved from 0.83310 to 0.85455, saving model to checkpoints/best_model.keras
#
# Epoch 2: finished saving model to checkpoints/best_model.keras
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 138s 187ms/step - accuracy: 0.8002 - loss: 0.6520 - val_accuracy: 0.8546 - val_loss: 0.4479 - learning_rate: 0.0010
# Epoch 3/20
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8292 - loss: 0.5097
# Epoch 3: val_accuracy improved from 0.85455 to 0.86142, saving model to checkpoints/best_model.keras
#
# Epoch 3: finished saving model to checkpoints/best_model.keras
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 100s 188ms/step - accuracy: 0.8330 - loss: 0.5101 - val_accuracy: 0.8614 - val_loss: 0.4100 - learning_rate: 0.0010
# Epoch 4/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8523 - loss: 0.4476
# Epoch 4: val_accuracy improved from 0.86142 to 0.88974, saving model to checkpoints/best_model.keras
#
# Epoch 4: finished saving model to checkpoints/best_model.keras
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 99s 185ms/step - accuracy: 0.8509 - loss: 0.4502 - val_accuracy: 0.8897 - val_loss: 0.3301 - learning_rate: 0.0010
# Epoch 5/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8670 - loss: 0.3951
# Epoch 5: val_accuracy did not improve from 0.88974
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 99s 187ms/step - accuracy: 0.8645 - loss: 0.4193 - val_accuracy: 0.8422 - val_loss: 0.4696 - learning_rate: 0.0010
# Epoch 6/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8670 - loss: 0.4021
# Epoch 6: val_accuracy did not improve from 0.88974
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 103s 193ms/step - accuracy: 0.8670 - loss: 0.3856 - val_accuracy: 0.8897 - val_loss: 0.3253 - learning_rate: 0.0010
# Epoch 7/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8858 - loss: 0.3420
# Epoch 7: val_accuracy did not improve from 0.88974
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 102s 191ms/step - accuracy: 0.8792 - loss: 0.3637 - val_accuracy: 0.8713 - val_loss: 0.3692 - learning_rate: 0.0010
# Epoch 8/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8861 - loss: 0.3342
# Epoch 8: val_accuracy improved from 0.88974 to 0.90184, saving model to checkpoints/best_model.keras
#
# Epoch 8: finished saving model to checkpoints/best_model.keras
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 95s 178ms/step - accuracy: 0.8828 - loss: 0.3456 - val_accuracy: 0.9018 - val_loss: 0.3109 - learning_rate: 0.0010
# Epoch 9/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8877 - loss: 0.3227
# Epoch 9: val_accuracy did not improve from 0.90184
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 92s 173ms/step - accuracy: 0.8868 - loss: 0.3319 - val_accuracy: 0.8977 - val_loss: 0.3154 - learning_rate: 0.0010
# Epoch 10/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8906 - loss: 0.3265
# Epoch 10: val_accuracy did not improve from 0.90184
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 101s 189ms/step - accuracy: 0.8885 - loss: 0.3196 - val_accuracy: 0.9002 - val_loss: 0.2899 - learning_rate: 0.0010
# Epoch 11/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9003 - loss: 0.2985
# Epoch 11: val_accuracy improved from 0.90184 to 0.90542, saving model to checkpoints/best_model.keras
#
# Epoch 11: finished saving model to checkpoints/best_model.keras
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 101s 191ms/step - accuracy: 0.9010 - loss: 0.2897 - val_accuracy: 0.9054 - val_loss: 0.2951 - learning_rate: 0.0010
# Epoch 12/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9031 - loss: 0.2925
# Epoch 12: val_accuracy did not improve from 0.90542
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 112s 211ms/step - accuracy: 0.9003 - loss: 0.3094 - val_accuracy: 0.8903 - val_loss: 0.3335 - learning_rate: 0.0010
# Epoch 13/20
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9069 - loss: 0.2512
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 13: val_accuracy did not improve from 0.90542
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 101s 190ms/step - accuracy: 0.9052 - loss: 0.2596 - val_accuracy: 0.8917 - val_loss: 0.3294 - learning_rate: 0.0010
# Epoch 14/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9197 - loss: 0.2304
# Epoch 14: val_accuracy did not improve from 0.90542
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 139s 184ms/step - accuracy: 0.9216 - loss: 0.2267 - val_accuracy: 0.9040 - val_loss: 0.2874 - learning_rate: 5.0000e-04
# Epoch 15/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9287 - loss: 0.1860
# Epoch 15: val_accuracy improved from 0.90542 to 0.91257, saving model to checkpoints/best_model.keras
#
# Epoch 15: finished saving model to checkpoints/best_model.keras
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 92s 173ms/step - accuracy: 0.9293 - loss: 0.1914 - val_accuracy: 0.9126 - val_loss: 0.2699 - learning_rate: 5.0000e-04
# Epoch 16/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9316 - loss: 0.1825
# Epoch 16: val_accuracy did not improve from 0.91257
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 147s 182ms/step - accuracy: 0.9303 - loss: 0.1895 - val_accuracy: 0.9109 - val_loss: 0.2819 - learning_rate: 5.0000e-04
# Epoch 17/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9319 - loss: 0.1865
# Epoch 17: val_accuracy did not improve from 0.91257
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 90s 170ms/step - accuracy: 0.9302 - loss: 0.1881 - val_accuracy: 0.9112 - val_loss: 0.2779 - learning_rate: 5.0000e-04
# Epoch 18/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9344 - loss: 0.1674
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 18: val_accuracy did not improve from 0.91257
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 89s 168ms/step - accuracy: 0.9333 - loss: 0.1806 - val_accuracy: 0.9032 - val_loss: 0.2851 - learning_rate: 5.0000e-04
# Epoch 19/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9362 - loss: 0.1704
# Epoch 19: val_accuracy improved from 0.91257 to 0.91696, saving model to checkpoints/best_model.keras
#
# Epoch 19: finished saving model to checkpoints/best_model.keras
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 144s 172ms/step - accuracy: 0.9379 - loss: 0.1667 - val_accuracy: 0.9170 - val_loss: 0.2483 - learning_rate: 2.5000e-04
# Epoch 20/20
# 530/531 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9421 - loss: 0.1483
# Epoch 20: val_accuracy did not improve from 0.91696
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 140s 168ms/step - accuracy: 0.9405 - loss: 0.1561 - val_accuracy: 0.9159 - val_loss: 0.2681 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 19.

# %%
def plot_history(history, title='Training'):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    ax1.plot(history.history['accuracy'],     label='Train', color='#3b6d11', lw=2)
    ax1.plot(history.history['val_accuracy'], label='Val',   color='#185fa5', lw=2, ls='--')
    ax1.set_title(f'{title} — Accuracy', fontweight='bold')
    ax1.set_xlabel('Epoch'); ax1.set_ylabel('Accuracy')
    ax1.legend(); ax1.grid(alpha=0.3); ax1.set_ylim(0, 1)

    ax2.plot(history.history['loss'],     label='Train', color='#a32d2d', lw=2)
    ax2.plot(history.history['val_loss'], label='Val',   color='#854f0b', lw=2, ls='--')
    ax2.set_title(f'{title} — Loss', fontweight='bold')
    ax2.set_xlabel('Epoch'); ax2.set_ylabel('Loss')
    ax2.legend(); ax2.grid(alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"history_{title.replace(' ','_').lower()}.png", dpi=120, bbox_inches='tight')
    plt.show()

plot_history(history, 'Feature Extraction')

# %% [markdown]
# ## 8. Evaluasi Model

# %%
# Load best checkpoint
model = keras.models.load_model('checkpoints/best_model.keras')

test_loss, test_acc = model.evaluate(test_ds, verbose=1)
print(f"\nTest Accuracy : {test_acc*100:.2f}%")
print(f"Test Loss     : {test_loss:.4f}")
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - accuracy: 0.9170 - loss: 0.2561
#
# Test Accuracy : 91.70%
# Test Loss     : 0.2561

# %%
y_pred_probs = model.predict(test_ds, verbose=1)
y_pred       = np.argmax(y_pred_probs, axis=1)
y_true       = y_test_idx

short_names = [f"{c.split('||')[0]}_{c.split('||')[2]}" for c in CLASS_NAMES]

print("\n" + "="*70)
print("CLASSIFICATION REPORT")
print("="*70)
print(classification_report(y_true, y_pred, target_names=short_names))
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 22s 155ms/step
#
# ======================================================================
# CLASSIFICATION REPORT
# ======================================================================
#                        precision    recall  f1-score   support
#
#           apple_Busuk       0.99      0.89      0.94       225
#          apple_Matang       0.99      0.96      0.98       225
#          apple_Mentah       0.79      0.85      0.81        13
#  apple_Terlalu Matang       0.69      1.00      0.82        50
#          banana_Busuk       0.97      0.92      0.95       225
#         banana_Matang       1.00      0.99      0.99       225
#         banana_Mentah       0.96      0.97      0.97        80
# banana_Terlalu Matang       0.69      0.94      0.79        49
#            cabe_Busuk       0.87      0.83      0.85        47
#            cabe_Segar       0.82      0.87      0.85        47
#          carrot_Busuk       0.92      0.90      0.91       225
#          carrot_Segar       0.91      0.93      0.92       225
#           grape_Busuk       0.95      0.86      0.90        91
#          grape_Matang       0.63      0.71      0.67        17
#          grape_Mentah       0.72      0.82      0.77        34
#  grape_Terlalu Matang       0.83      1.00      0.90        19
#           mango_Busuk       0.84      0.70      0.76        89
#          mango_Matang       0.95      0.96      0.95        91
#          mango_Mentah       0.80      0.74      0.77        27
#  mango_Terlalu Matang       0.30      0.65      0.41        17
#          orange_Busuk       0.95      0.92      0.94       225
#         orange_Matang       0.97      0.92      0.95       225
#         orange_Mentah       0.58      0.78      0.67         9
# orange_Terlalu Matang       0.39      0.78      0.52         9
#          potato_Busuk       0.94      0.82      0.88       208
#          potato_Segar       0.86      0.97      0.91       172
#           timun_Busuk       0.97      0.91      0.94       152
#           timun_Segar       0.95      0.98      0.97       166
#           tomat_Busuk       0.90      0.98      0.94       225
#           tomat_Segar       0.98      0.92      0.95       225
#
#              accuracy                           0.92      3637
#             macro avg       0.84      0.88      0.85      3637
#          weighted avg       0.93      0.92      0.92      3637

# %%
# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(max(10, NUM_CLASSES), max(8, NUM_CLASSES - 2)))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=short_names, yticklabels=short_names,
    ax=ax, linewidths=0.3, annot_kws={'size': 7}
)
ax.set_xlabel('Prediksi', fontsize=11)
ax.set_ylabel('Aktual',   fontsize=11)
ax.set_title('Confusion Matrix', fontsize=14, fontweight='bold', pad=15)
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(rotation=0,  fontsize=8)
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Accuracy per item & kondisi
print(f"{'Item':<15} {'Jenis':<7} {'Kondisi':<16} {'Accuracy':>9} {'N':>6}")
print("-" * 57)

rows = []
for cls_label in CLASS_NAMES:
    nama, jenis, kondisi = cls_label.split('||')
    idx  = label2idx[cls_label]
    mask = y_true == idx
    if mask.sum() == 0:
        continue
    acc = (y_pred[mask] == idx).mean()
    rows.append({'Item': nama, 'Jenis': jenis,
                 'Kondisi': kondisi, 'Accuracy': acc, 'N': mask.sum()})
    print(f"{nama:<15} {jenis:<7} {kondisi:<16} {acc*100:>8.1f}% {mask.sum():>6}")

df_acc = pd.DataFrame(rows)

# Heatmap accuracy
pivot_buah  = df_acc[df_acc['Jenis']=='Buah'].pivot(
    index='Item', columns='Kondisi', values='Accuracy')
pivot_sayur = df_acc[df_acc['Jenis']=='Sayur'].pivot(
    index='Item', columns='Kondisi', values='Accuracy')

fig, axes = plt.subplots(1, 2, figsize=(16, max(5, len(df_acc['Item'].unique())//2)))
for ax, (pivot, title) in zip(axes, [
    (pivot_buah,  'Accuracy per Item — Buah'),
    (pivot_sayur, 'Accuracy per Item — Sayur')
]):
    if pivot is not None and not pivot.empty:
        sns.heatmap(pivot * 100, annot=True, fmt='.1f', cmap='RdYlGn',
                    vmin=0, vmax=100, ax=ax, linewidths=0.5, annot_kws={'size': 9})
        ax.set_title(title, fontweight='bold')
        ax.set_xlabel('Kondisi Fisik')
        ax.set_ylabel('Nama Item')

plt.tight_layout()
plt.savefig('accuracy_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# Item            Jenis   Kondisi           Accuracy      N
# ---------------------------------------------------------
# apple           Buah    Busuk                88.9%    225
# apple           Buah    Matang               96.4%    225
# apple           Buah    Mentah               84.6%     13
# apple           Buah    Terlalu Matang      100.0%     50
# banana          Buah    Busuk                92.0%    225
# banana          Buah    Matang               98.7%    225
# banana          Buah    Mentah               97.5%     80
# banana          Buah    Terlalu Matang       93.9%     49
# cabe            Sayur   Busuk                83.0%     47
# cabe            Sayur   Segar                87.2%     47
# carrot          Sayur   Busuk                89.8%    225
# carrot          Sayur   Segar                92.9%    225
# grape           Buah    Busuk                85.7%     91
# grape           Buah    Matang               70.6%     17
# grape           Buah    Mentah               82.4%     34
# grape           Buah    Terlalu Matang      100.0%     19
# mango           Buah    Busuk                69.7%     89
# mango           Buah    Matang               95.6%     91
# mango           Buah    Mentah               74.1%     27
# mango           Buah    Terlalu Matang       64.7%     17
# orange          Buah    Busuk                92.0%    225
# orange          Buah    Matang               92.4%    225
# orange          Buah    Mentah               77.8%      9
# orange          Buah    Terlalu Matang       77.8%      9
# potato          Sayur   Busuk                82.2%    208
# potato          Sayur   Segar                97.1%    172
# timun           Sayur   Busuk                91.4%    152
# timun           Sayur   Segar                98.2%    166
# tomat           Sayur   Busuk                97.8%    225
# tomat           Sayur   Segar                92.0%    225

# %% [markdown]
# ## 9. Prediksi Gambar Baru + Out-of-Scope Detection
#
# **Strategi mendeteksi gambar di luar cakupan (sepatu, hewan, dll.):**
#
# 1. **Confidence threshold**: Jika probabilitas prediksi tertinggi `max(softmax) < 0.60`, berarti model tidak cukup yakin → tolak input.
# 2. **Entropy check**: Jika nilai entropi `> 2.8`, menandakan distribusi probabilitas menyebar merata (model kebingungan) → tolak input.
#    - **In-scope (Gambar valid):** Model sangat yakin pada 1 atau 2 kelas (distribusi menukik/peaked) → nilai entropi rendah.
#    - **Out-of-scope (Gambar asing):** Model membagi probabilitas ke banyak kelas karena tidak ada yang cocok (distribusi merata) → nilai entropi tinggi (mendekati batas maksimal log(30) ≈ 3.40).
#
# Jika salah satu atau kedua kondisi ini terpenuhi, gambar akan ditolak. Pendekatan ini *tidak 100% sempurna* (karena arsitektur dasar model kadang bisa mengalami *overconfidence* pada gambar asing), namun jauh lebih praktis dan hemat memori dibandingkan harus melatih ulang model dengan tambahan ribuan "dataset negatif".

# %%
def compute_entropy(probs):
    """Shannon entropy dari distribusi probabilitas softmax."""
    probs = np.clip(probs, 1e-9, 1.0)  # hindari log(0)
    return -np.sum(probs * np.log(probs))


def predict_image(img_path, model,
                  class_names=CLASS_NAMES,
                  img_size=IMG_SIZE,
                  confidence_threshold=CONFIDENCE_THRESHOLD,
                  entropy_threshold=ENTROPY_THRESHOLD,
                  top_k=5):
    """
    Prediksi satu gambar dengan out-of-scope detection.

    Returns:
        dict dengan keys:
          - status         : 'OK' atau 'OUT_OF_SCOPE'
          - nama_item      : nama item (apple, cabe, dst.) — None jika out-of-scope
          - jenis_item     : 'Buah' atau 'Sayur'
          - kondisi_fisik  : kondisi
          - confidence     : persentase keyakinan
          - entropy        : nilai entropy softmax
          - reason         : penjelasan jika out-of-scope
    """
    img     = load_img(img_path, target_size=(img_size, img_size))
    img_arr = img_to_array(img) / 255.0
    img_arr = np.expand_dims(img_arr, axis=0)

    probs      = model.predict(img_arr, verbose=0)[0]
    confidence = float(np.max(probs))
    entropy    = compute_entropy(probs)

    top_indices = probs.argsort()[::-1][:top_k]

    # Out-of-scope detection
    reasons = []
    if confidence < confidence_threshold:
        reasons.append(f"confidence rendah ({confidence*100:.1f}% < {confidence_threshold*100:.0f}%)")
    if entropy > entropy_threshold:
        reasons.append(f"entropy tinggi ({entropy:.2f} > {entropy_threshold:.2f})")

    KONDISI_COLOR = {
        'Mentah': '#aed6a0', 'Matang': '#3b6d11',
        'Terlalu Matang': '#854f0b', 'Busuk': '#a32d2d', 'Segar': '#3b6d11',
    }

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 4.5))
    ax1.imshow(img); ax1.axis('off')

    bar_labels, bar_values, bar_colors = [], [], []
    for i in top_indices[::-1]:
        n, j, k = class_names[i].split('||')
        bar_labels.append(f"{n} — {k}")
        bar_values.append(probs[i] * 100)
        bar_colors.append(KONDISI_COLOR.get(k, '#333'))

    bars = ax2.barh(bar_labels, bar_values, color=bar_colors, alpha=0.85)
    ax2.bar_label(bars, fmt='%.2f%%', padding=3, fontsize=9)
    ax2.set_xlabel('Confidence (%)')
    ax2.set_title(f'Top-{top_k} Prediksi', fontweight='bold')
    ax2.set_xlim(0, 115)
    ax2.grid(axis='x', alpha=0.3)

    if reasons:
        # OUT OF SCOPE
        status = 'OUT_OF_SCOPE'
        reason_str = '; '.join(reasons)
        plt.suptitle(
            f"⚠️  TIDAK DIKENALI\n{reason_str}",
            fontsize=12, fontweight='bold', color='#cc0000', y=1.02
        )
        result = {
            'status'        : status,
            'nama_item'     : None,
            'jenis_item'    : None,
            'kondisi_fisik' : None,
            'confidence'    : f"{confidence*100:.2f}%",
            'entropy'       : f"{entropy:.3f}",
            'reason'        : reason_str
        }
    else:
        # IN SCOPE
        top_label = class_names[top_indices[0]]
        nama, jenis, kondisi = top_label.split('||')
        color = KONDISI_COLOR.get(kondisi, '#333')
        plt.suptitle(
            f"{nama.title()} ({jenis}) — {kondisi}  [{confidence*100:.1f}%]",
            fontsize=13, fontweight='bold', color=color, y=1.02
        )
        result = {
            'status'        : 'OK',
            'nama_item'     : nama,
            'jenis_item'    : jenis,
            'kondisi_fisik' : kondisi,
            'confidence'    : f"{confidence*100:.2f}%",
            'entropy'       : f"{entropy:.3f}",
            'reason'        : None
        }

    plt.tight_layout()
    plt.show()

    print("\n=== Hasil Prediksi ===")
    for k, v in result.items():
        if v is not None:
            print(f"  {k:<15}: {v}")
    return result

# %%
# Contoh pemakaian
IMG_PATH = "test-image-in-scope.jpg"   # ganti dengan path gambar

if os.path.exists(IMG_PATH):
    result = predict_image(IMG_PATH, model)
else:
    print(f"File '{IMG_PATH}' tidak ditemukan.")
    print("Ganti IMG_PATH dengan path gambar yang ingin diprediksi.")
    print("\nContoh:")
    print('  result = predict_image("/path/to/apple.jpg", model)')
    print('  result = predict_image("/path/to/foto_hewan.jpg", model)  # akan OUT_OF_SCOPE')
# Out:
# === Hasil Prediksi ===
#   status         : OK
#   nama_item      : banana
#   jenis_item     : Buah
#   kondisi_fisik  : Mentah
#   confidence     : 99.93%
#   entropy        : 0.007

# %%
# Contoh pemakaian
IMG_PATH = "test-image-out-of-scope.jpg"   # ganti dengan path gambar

if os.path.exists(IMG_PATH):
    result = predict_image(IMG_PATH, model)
else:
    print(f"File '{IMG_PATH}' tidak ditemukan.")
    print("Ganti IMG_PATH dengan path gambar yang ingin diprediksi.")
    print("\nContoh:")
    print('  result = predict_image("/path/to/apple.jpg", model)')
    print('  result = predict_image("/path/to/foto_hewan.jpg", model)  # akan OUT_OF_SCOPE')
# Out:
# === Hasil Prediksi ===
#   status         : OUT_OF_SCOPE
#   confidence     : 49.62%
#   entropy        : 1.263
#   reason         : confidence rendah (49.6% < 60%)

# %% [markdown]
# ## 10. Evaluasi Out-of-Scope Threshold
#
# Gunakan cell ini untuk menyetel threshold menggunakan data test yang ada.
# Kita simulasikan "out-of-scope" dengan melihat distribusi entropy gambar in-scope,
# lalu tentukan batas yang wajar.

# %%
# Distribusi confidence & entropy pada test set (in-scope)
print("Menghitung entropy pada test set...")

all_conf    = []
all_entropy = []

for batch_imgs, _ in test_ds:
    probs_batch = model.predict(batch_imgs, verbose=0)
    for p in probs_batch:
        all_conf.append(float(np.max(p)))
        all_entropy.append(compute_entropy(p))

all_conf    = np.array(all_conf[:len(y_test_idx)])
all_entropy = np.array(all_entropy[:len(y_test_idx)])

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

axes[0].hist(all_conf, bins=50, color='#3b6d11', alpha=0.7, edgecolor='white')
axes[0].axvline(CONFIDENCE_THRESHOLD, color='red', ls='--',
                label=f'Threshold = {CONFIDENCE_THRESHOLD}')
axes[0].set_title('Distribusi Max-Confidence (In-Scope)', fontweight='bold')
axes[0].set_xlabel('Confidence'); axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].hist(all_entropy, bins=50, color='#185fa5', alpha=0.7, edgecolor='white')
axes[1].axvline(ENTROPY_THRESHOLD, color='red', ls='--',
                label=f'Threshold = {ENTROPY_THRESHOLD}')
axes[1].axvline(np.log(NUM_CLASSES), color='orange', ls=':',
                label=f'Uniform entropy = {np.log(NUM_CLASSES):.2f}')
axes[1].set_title('Distribusi Entropy Softmax (In-Scope)', fontweight='bold')
axes[1].set_xlabel('Entropy'); axes[1].legend(); axes[1].grid(alpha=0.3)

plt.suptitle('Panduan Penentuan Threshold Out-of-Scope', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.savefig('threshold_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"\nStatistik Confidence (in-scope test):")
print(f"  Mean   : {all_conf.mean():.3f}")
print(f"  P5     : {np.percentile(all_conf, 5):.3f}  (5% gambar in-scope di bawah ini)")
print(f"  P1     : {np.percentile(all_conf, 1):.3f}")
print(f"\nStatistik Entropy (in-scope test):")
print(f"  Mean   : {all_entropy.mean():.3f}")
print(f"  P95    : {np.percentile(all_entropy, 95):.3f}")
print(f"  P99    : {np.percentile(all_entropy, 99):.3f}")
print(f"\n💡 Saran threshold:")
print(f"   CONFIDENCE_THRESHOLD = {np.percentile(all_conf, 5):.2f}  (P5 confidence)")
print(f"   ENTROPY_THRESHOLD    = {np.percentile(all_entropy, 95):.2f}  (P95 entropy)")
# Out:
# Menghitung entropy pada test set...
# Statistik Confidence (in-scope test):
#   Mean   : 0.942
#   P5     : 0.623  (5% gambar in-scope di bawah ini)
#   P1     : 0.489
#
# Statistik Entropy (in-scope test):
#   Mean   : 0.158
#   P95    : 0.709
#   P99    : 1.307
#
# 💡 Saran threshold:
#    CONFIDENCE_THRESHOLD = 0.62  (P5 confidence)
#    ENTROPY_THRESHOLD    = 0.71  (P95 entropy)

# %% [markdown]
# ## 11. Simpan & Export Model

# %%
# Simpan model Keras
model.save('sayur_buah_classifier.keras')
print("Saved: sayur_buah_classifier.keras")

# Simpan metadata lengkap (termasuk threshold)
meta = {
    'class_names'          : CLASS_NAMES,
    'label2idx'            : label2idx,
    'num_classes'          : NUM_CLASSES,
    'img_size'             : IMG_SIZE,
    'label_format'         : 'nama_item||jenis_item||kondisi_fisik',
    'confidence_threshold' : CONFIDENCE_THRESHOLD,
    'entropy_threshold'    : ENTROPY_THRESHOLD,
    'entropy_uniform_30cls': float(np.log(NUM_CLASSES)),
    'jenis_item': {
        'Buah' : ['Mentah', 'Matang', 'Terlalu Matang', 'Busuk'],
        'Sayur': ['Segar', 'Busuk']
    }
}
with open('model_metadata.json', 'w') as f:
    json.dump(meta, f, indent=2, ensure_ascii=False)
print("Saved: model_metadata.json")
# Out:
# Saved: sayur_buah_classifier.keras
# Saved: model_metadata.json

# %%
# Export TFLite

saved_model_dir = 'saved_model'
os.makedirs(saved_model_dir, exist_ok=True)
os.makedirs('tflite', exist_ok=True)

try:
    model.export(saved_model_dir)
except AttributeError:
    model.save(saved_model_dir)
print(f"SavedModel tersimpan di: {saved_model_dir}/")

converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

tflite_path = 'tflite/sayur_buah_classifier.tflite'
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)

size_mb = os.path.getsize(tflite_path) / (1024**2)
print(f"Saved: {tflite_path} ({size_mb:.1f} MB)")

# Simpan label.txt
with open('tflite/label.txt', 'w') as f:
    for cls in CLASS_NAMES:
        f.write(cls + '\n')
print("Saved: tflite/label.txt")
print("Siap deploy ke Android/iOS!")
# Out:
# Saved artifact at 'saved_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 30), dtype=tf.float32, name=None)
# Captures:
#   139542821508432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821509200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821507472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821506512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821509776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821510160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821510352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821509392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821509968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821510928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821505360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821510544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821510736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821506128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821511888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821511312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821511504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821511696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821509008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821512848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821512272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821512464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821512656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821509584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821513808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821513232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821513424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821513616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821511120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821514768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821514192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821514384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821514576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821512080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821515728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821515152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821515344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821515536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821513040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821516688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821516112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821516304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821516496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821514000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821517648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821517072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821517264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821517456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821514960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821518608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821518032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821518224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821518800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821519184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821517840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821516880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821518416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362374800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821518992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542821515920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362374416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362375184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362374992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362374224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362376336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362375760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362375952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362376144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362375376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362377296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362376720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362376912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362377104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362374608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362378256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362377680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362377872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362378064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362375568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362379216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362378640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362378832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362379024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362376528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362380176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362379600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362379792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362379984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362377488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362381136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362380560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362380752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362380944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362378448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362382096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362381520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362381712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362381904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362379408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362383056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362382480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362382672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362382864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362380368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362384016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362383440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362383632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362383824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362381328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362384976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362384400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362384592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362384784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362382288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362385936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362385360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362385552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362385744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362383248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362386896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362386320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362386512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362386704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362384208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362387856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362387280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362387472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362387664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362385168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362388816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362388240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362388432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362388624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362386128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362389776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362389200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362389392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362389968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362390352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362389008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362388048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362389584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363242960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362390160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362387088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363242768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363243536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363243152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363244688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363244112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363244304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363245648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363245072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363245264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363245456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363242576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363246608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363246032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363246224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363246416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363243920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363247568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363246992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363247184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363247376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363244880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363248528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363247952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363248144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363248336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363245840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363249488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363248912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363249104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363249296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363246800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363250448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363249872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363250256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363247760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363251408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363250832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363251024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363251216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363248720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363252368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363251792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363251984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363252176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363249680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363253328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363252752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363252944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363253136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363250640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363254288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363253712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363253904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363254096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363251600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363255248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363254672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363254864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363255056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363252560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363256208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363255632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363255824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363256016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363253520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363257168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363256592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363256784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363256976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363254480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363258128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363257552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363257744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363258320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363258704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363257360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363256400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363257936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362014160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363258512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542363255440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362013968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362014736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362014544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362014352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362015888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362015312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362015504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362015696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362014928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362016848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362016272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362016464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362016656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362013776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362017808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362017232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362017424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362017616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362015120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362018768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362018192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362018384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362018576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362016080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362019728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362019152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362019344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362019536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362017040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362020688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362021072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362020496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362021456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139542362022032: TensorSpec(shape=(), dtype=tf.resource, name=None)
# SavedModel tersimpan di: saved_model/
# Saved: tflite/sayur_buah_classifier.tflite (2.7 MB)
# Saved: tflite/label.txt
# Siap deploy ke Android/iOS!

# %%
print("=" * 65)
print("RINGKASAN")
print("=" * 65)
print(f"  Model          : MobileNetV2 (pretrained ImageNet, frozen)")
print(f"  Input          : {IMG_SIZE}×{IMG_SIZE}×3")
print(f"  Total kelas    : {NUM_CLASSES}")
print(f"  Train          : {len(X_train):,}")
print(f"  Val            : {len(X_val):,}")
print(f"  Test           : {len(X_test):,}")
print(f"  Test Accuracy  : {test_acc*100:.2f}%")
print(f"  Test Loss      : {test_loss:.4f}")
print(f"  Class weight   : balanced (sklearn compute_class_weight)")
print(f"  Augmentasi     : on-the-fly (flip, crop, brightness, contrast, saturation)")
print(f"  Conf threshold : {CONFIDENCE_THRESHOLD} (out-of-scope rejection)")
print(f"  Entropy thresh : {ENTROPY_THRESHOLD} (uniform={np.log(NUM_CLASSES):.2f})")
print()
print("Label standar output:")
print("  Buah  → Mentah | Matang | Terlalu Matang | Busuk")
print("  Sayur → Segar  | Busuk")
print()
print("File output:")
print("  sayur_buah_classifier.keras          → model Keras")
print("  tflite/sayur_buah_classifier.tflite  → untuk mobile")
print("  tflite/label.txt                     → daftar kelas")
print("  model_metadata.json                  → metadata & threshold")
print("  confusion_matrix.png")
print("  accuracy_heatmap.png")
print("  threshold_analysis.png")
# Out:
# =================================================================
# RINGKASAN
# =================================================================
#   Model          : MobileNetV2 (pretrained ImageNet, frozen)
#   Input          : 224×224×3
#   Total kelas    : 30
#   Train          : 16,968
#   Val            : 3,637
#   Test           : 3,637
#   Test Accuracy  : 91.70%
#   Test Loss      : 0.2561
#   Class weight   : balanced (sklearn compute_class_weight)
#   Augmentasi     : on-the-fly (flip, crop, brightness, contrast, saturation)
#   Conf threshold : 0.6 (out-of-scope rejection)
#   Entropy thresh : 2.8 (uniform=3.40)
#
# Label standar output:
#   Buah  → Mentah | Matang | Terlalu Matang | Busuk
#   Sayur → Segar  | Busuk
#
# File output:
#   sayur_buah_classifier.keras          → model Keras
#   tflite/sayur_buah_classifier.tflite  → untuk mobile
#   tflite/label.txt                     → daftar kelas
#   model_metadata.json                  → metadata & threshold
#   confusion_matrix.png
#   accuracy_heatmap.png
#   threshold_analysis.png

# %%
# Mengompresi folder 'saved_model' menjadi 'saved_model.zip'
shutil.make_archive('saved_model', 'zip', 'saved_model')

print("Folder saved_model berhasil dikompresi menjadi zip!")
# Out:
# Folder saved_model berhasil dikompresi menjadi zip!

# %%
# Mengompresi folder 'tflite' menjadi 'tflite.zip'
shutil.make_archive('tflite', 'zip', 'tflite')

print("Folder tflite berhasil dikompresi menjadi zip!")
# Out:
# Folder tflite berhasil dikompresi menjadi zip!
